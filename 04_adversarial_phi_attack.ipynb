# %% [markdown]
# <a href="https://colab.research.google.com/github/georgezero/rsna25-deid-using-chatgpt-llms/blob/main/04_adversarial_phi_attack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Adversarial PHI Hunter: Red Team Your Deidentification
#
# **The uncomfortable truth:** Even after removing obvious PHI (names, dates, IDs), a motivated attacker with an LLM might still be able to infer sensitive information about a patient.
#
# In this notebook, we'll flip the script. Instead of *removing* PHI, we'll try to *recover* information from supposedly deidentified reports. This exercise demonstrates:
#
# 1. **Quasi-identifiers** - Combinations of non-PHI data that can identify individuals
# 2. **Inference attacks** - What an LLM can deduce from clinical context
# 3. **The limits of simple deidentification** - Why redaction alone isn't always enough
#
# **Important:** This is an educational exercise to understand privacy risks. The goal is to build better deidentification practices.

# %% [markdown]
# ## Quick start
# - Run the `pip install` cell.
# - Get a free API key from [Google AI Studio](https://aistudio.google.com/app/apikey).
# - Set your `GOOGLE_API_KEY` in the code below.

# %%
# Install dependencies
# %pip install -q -U google-generativeai

# %% [markdown]
# You will need to create an API key. Click the link for a quick tutorial: [Tutorial](https://drive.google.com/file/d/1fGoSsapol9JY9oqu-UulLJfMm-v2egWC/view?usp=drive_link)

# %%
import os
import google.generativeai as genai

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY") or "PASTE_YOUR_KEY_HERE"

if GOOGLE_API_KEY == "PASTE_YOUR_KEY_HERE":
    print("⚠️ Please paste your Google API Key in the variable above.")
else:
    genai.configure(api_key=GOOGLE_API_KEY)
    print("✅ Gemini API configured")
# Out:
# ✅ Gemini API configured

# %% [markdown]
# ## Scenario: A "Properly" Deidentified Report
#
# Below is a radiology report that has been deidentified following standard practices:
# - Patient name → removed
# - MRN → removed
# - Dates → removed
# - Physician names → removed
#
# Looks safe, right? Let's see what an LLM can figure out...

# %%
# This report has had "standard" PHI removed
deidentified_report_1 = """
EXAMINATION: MRI LEFT HAND WITHOUT CONTRAST

CLINICAL HISTORY: Professional violinist with 2-month history of left 4th finger pain
and weakness affecting performance. Patient reports practicing 6-8 hours daily for
upcoming solo debut at [REDACTED] Symphony Orchestra.

COMPARISON: None available.

TECHNIQUE: Multiplanar multisequence MRI of the left hand was performed on a 3T scanner.

FINDINGS:
There is intermediate T2 signal and mild enhancement within the A2 pulley of the
4th digit, consistent with stenosing tenosynovitis (trigger finger).
Mild associated flexor digitorum superficialis and profundus tenosynovitis is noted.
The extensor mechanism is intact.
No evidence of fracture or osseous abnormality.
The triangular fibrocartilage complex is intact.

IMPRESSION:
1. Stenosing tenosynovitis (trigger finger) of the left 4th digit with associated
   flexor tenosynovitis, likely related to repetitive strain from instrument playing.
2. Recommend hand therapy consultation and activity modification.

Electronically signed.
"""

print("=" * 60)
print("DEIDENTIFIED REPORT #1")
print("=" * 60)
print(deidentified_report_1)
# Out:
# ============================================================
# DEIDENTIFIED REPORT #1
# ============================================================
#
# EXAMINATION: MRI LEFT HAND WITHOUT CONTRAST
#
# CLINICAL HISTORY: Professional violinist with 2-month history of left 4th finger pain
# and weakness affecting performance. Patient reports practicing 6-8 hours daily for
# upcoming solo debut at [REDACTED] Symphony Orchestra.
#
# COMPARISON: None available.
#
# TECHNIQUE: Multiplanar multisequence MRI of the left hand was performed on a 3T scanner.
#
# FINDINGS:
# There is intermediate T2 signal and mild enhancement within the A2 pulley of the
# 4th digit, consistent with stenosing tenosynovitis (trigger finger).
# Mild associated flexor digitorum superficialis and profundus tenosynovitis is noted.
# The extensor mechanism is intact.
# No evidence of fracture or osseous abnormality.
# The triangular fibrocartilage complex is intact.
#
# IMPRESSION:
# 1. Stenosing tenosynovitis (trigger finger) of the left 4th digit with associated
#    flexor tenosynovitis, likely related to repetitive strain from instrument playing.
# 2. Recommend hand therapy consultation and activity modification.
#
# Electronically signed.

# %% [markdown]
# ## Attack #1: Demographic Inference
#
# Let's ask the LLM what it can infer about the patient from the "deidentified" report.

# %%
model = genai.GenerativeModel('models/gemini-2.0-flash-lite')

inference_prompt = """
You are a privacy researcher analyzing deidentified medical records for re-identification risks.

Based ONLY on the information in this "deidentified" radiology report, what can you infer or
deduce about the patient? Consider:

1. Likely age range
2. Gender (if inferable)
3. Occupation details
4. Skill level / career stage
5. Geographic hints
6. Socioeconomic indicators
7. Any other identifying characteristics

For each inference, explain your reasoning and rate confidence (Low/Medium/High).

Report:
"""

response = model.generate_content(inference_prompt + deidentified_report_1)
print("INFERENCE ATTACK RESULTS:")
print("=" * 60)
print(response.text)
# Out:
# INFERENCE ATTACK RESULTS:
# ============================================================
# Here's an analysis of the deidentified radiology report, outlining potential inferences and associated confidence levels:
#
# 1.  **Likely Age Range:**
#     *   **Inference:** The patient is likely an adult, given the context of a "professional violinist" and a "solo debut."  While young musicians exist, the level of career stage suggests an older age.
#     *   **Reasoning:** The report mentions a "solo debut" and the "upcoming" nature of it suggesting that the patient has put in a lot of time and dedication to get to this point, which takes time.
#     *   **Confidence:** Medium
#
# 2.  **Gender:**
#     *   **Inference:** It is impossible to determine the gender based on the limited information.
#     *   **Reasoning:** The report does not mention any clues to the patient's gender.
#     *   **Confidence:** Low
#
# 3.  **Occupation Details:**
#     *   **Inference:** Professional violinist.
#     *   **Reasoning:** This is explicitly stated in the "Clinical History."
#     *   **Confidence:** High
#
# 4.  **Skill Level / Career Stage:**
#     *   **Inference:** High skill level and a developing professional career. Likely nearing the peak of their performance skills
#     *   **Reasoning:** The patient is a "professional violinist" and is preparing for a "solo debut." The fact that they are at this level suggests they have dedicated a substantial amount of time practicing and improving their skill.
#     *   **Confidence:** High
#
# 5.  **Geographic Hints:**
#     *   **Inference:** The patient is connected to the city where the "[REDACTED] Symphony Orchestra" is located.
#     *   **Reasoning:** The report explicitly mentions the symphony orchestra where the patient's solo debut is.
#     *   **Confidence:** Medium (This could change if other information were available)
#
# 6.  **Socioeconomic Indicators:**
#     *   **Inference:** Likely middle to upper-middle class or wealthy.
#     *   **Reasoning:**
#         *   **Musical Training:**  Classical musical training at a professional level often requires access to expensive instruments, private lessons, and significant time and resources.
#         *   **Professional Career:**  Securing a solo debut with a symphony orchestra implies a high degree of talent and connections, which may be fostered by a privileged upbringing and training.
#         *   **Medical Care:** The patient has access to an MRI, which is a relatively expensive and specialized diagnostic tool.
#     *   **Confidence:** Medium
#
# 7.  **Other Identifying Characteristics:**
#     *   **Inference:**  The patient is highly dedicated to their craft and possibly under a great deal of performance pressure.  They may also be experiencing a decrease in quality of life due to the medical issue.
#     *   **Reasoning:** The report indicates they practice a substantial amount of hours, 6-8 per day. This amount of time, alongside the pain, implies they take the career very seriously.
#     *   **Confidence:** Medium

# %% [markdown]
# ## Attack #2: Uniqueness Analysis
#
# How unique is this combination of characteristics? Could we narrow down the patient pool?

# %%
uniqueness_prompt = """
You are analyzing this deidentified report for re-identification risk.

Consider the combination of quasi-identifiers present:
- Occupation: Professional violinist
- Specific detail: Upcoming solo debut
- Venue hint: Symphony Orchestra
- Condition: Left 4th finger trigger finger
- Practice intensity: 6-8 hours daily

Questions:
1. How many professional violinists have solo debuts at major symphony orchestras in a given year?
2. Of those, how many would have this specific finger condition?
3. If someone had access to public concert schedules and this report, could they identify the patient?
4. What's the estimated "anonymity set" size (how many people could this possibly be)?

Provide your analysis of re-identification feasibility.

Report:
"""

response = model.generate_content(uniqueness_prompt + deidentified_report_1)
print("UNIQUENESS ANALYSIS:")
print("=" * 60)
print(response.text)
# Out:
# UNIQUENESS ANALYSIS:
# ============================================================
# Here's a breakdown of the re-identification risk analysis:
#
# **1. How many professional violinists have solo debuts at major symphony orchestras in a given year?**
#
# *   **Analysis:** This is the most crucial question. The answer will heavily influence the anonymity set size.  The number is likely very small. Consider the following:
#     *   **Professional Violinists:** There are many professional violinists, but the number who perform with major symphony orchestras is a much smaller subset.
#     *   **Solo Debut:** A solo debut is a significant career milestone, and a limited number of violinists achieve this.
#     *   **Major Symphony Orchestra:**  "Major" suggests highly prominent orchestras (e.g., Boston Symphony, New York Philharmonic, London Symphony). These are the most competitive engagements.
# *   **Estimation:**  Likely **less than 10 per orchestra per year**, and possibly even less than 1. Some years, a specific orchestra might not have any solo debuts by violinists.
#
# **2. Of those, how many would have this specific finger condition?**
#
# *   **Analysis:** This significantly narrows the field. Trigger finger, especially in musicians, is a relatively common condition due to repetitive strain. However, it affects a subset of all violinists. The fact that it's the *left* 4th finger adds some specificity (though this is the typical finger affected).
# *   **Estimation:** Assuming a small percentage of soloists (e.g., 5-10%) experience this type of injury, further reducing the chances. It's safe to assume a number between **0 and 1** based on the data.
#
# **3. If someone had access to public concert schedules and this report, could they identify the patient?**
#
# *   **Analysis:** **High Risk.** This is the crux of the problem. Here's why:
#     *   **Public Concert Schedules:** Concert schedules of major orchestras are typically public information (websites, press releases, etc.). This allows someone to identify potential candidates for the solo debut.
#     *   **Matching:** An individual could examine the concert schedules of the [REDACTED] Symphony Orchestra and look for upcoming solo violin performances. If they find only one or two, the likelihood of a match is very high.
#     *   **Confirmation:** The additional information (finger condition and practice habits) acts as very strong corroboration. If they can identify a soloist who fits this profile, they likely have a match.
#     *   **Venue Hint:** The orchestra's name is redacted, but if that could be figured out, it lowers the risk to high.
# *   **Conclusion:** The combination of quasi-identifiers combined with access to public concert schedules poses a significant re-identification risk.
#
# **4. What's the estimated "anonymity set" size (how many people could this possibly be)?**
#
# *   **Analysis:** Based on the previous points, the anonymity set is likely extremely small.
# *   **Estimation:**  The most reasonable estimate, based on the above analysis, is likely **1 or 2**. It could even be a certainty. The solo debut is the key factor limiting the size of the set.
#
# **Overall Re-identification Feasibility:**
#
# **High**. The combination of the specialized profession, specific detail (upcoming solo debut at a major orchestra), and the medical condition creates a highly identifiable profile. Access to public concert schedules significantly increases the re-identification risk, effectively reducing the anonymity set to a very small number (possibly even one).  The information provided is not properly de-identified and at risk.
#
# **Recommendations:**
#
# *   **Redact the orchestra name** This has been done. If this is known or can be found, the risk is at the top.
# *   **Consider de-identifying the diagnosis** Remove details, i.e. "finger condition" instead of "left 4th finger trigger finger".
# *   **Consider generalizing the practice time** "Regular practice of instrument".
# *   **Remove or generalize the clinical history**
# *   **Do not include any identifying features**

# %% [markdown]
# ## Let's Try Another Report
#
# Here's a different scenario with different quasi-identifiers.

# %%
deidentified_report_2 = """
EXAMINATION: CT CHEST WITH CONTRAST

CLINICAL HISTORY: Former professional athlete (NFL linebacker, 12 seasons) presenting
with dyspnea on exertion. History of multiple documented concussions.
BMI 34. Non-smoker. Retired 3 years ago.

COMPARISON: Chest X-ray from [REDACTED].

TECHNIQUE: Helical CT of the chest performed with IV contrast.

FINDINGS:
HEART: Cardiomegaly with left ventricular hypertrophy pattern.
Coronary artery calcifications noted in the LAD (Agatston score ~180).

LUNGS: Clear bilaterally. No pulmonary nodules or masses.
No pleural effusion or pneumothorax.

MEDIASTINUM: No lymphadenopathy. Normal caliber thoracic aorta.

MUSCULOSKELETAL: Incidental note of healed right clavicle fracture with hardware.
Degenerative changes in the cervical spine with multilevel disc disease.
Old healed rib fractures on the right (ribs 7, 8).

IMPRESSION:
1. Cardiomegaly with LVH, likely athletic heart with possible early
   hypertensive changes. Cardiology follow-up recommended.
2. Moderate coronary artery calcification - consider risk stratification.
3. Chronic musculoskeletal changes consistent with prior athletic injuries.

Electronically signed.
"""

print("=" * 60)
print("DEIDENTIFIED REPORT #2")
print("=" * 60)
print(deidentified_report_2)
# Out:
# ============================================================
# DEIDENTIFIED REPORT #2
# ============================================================
#
# EXAMINATION: CT CHEST WITH CONTRAST
#
# CLINICAL HISTORY: Former professional athlete (NFL linebacker, 12 seasons) presenting
# with dyspnea on exertion. History of multiple documented concussions.
# BMI 34. Non-smoker. Retired 3 years ago.
#
# COMPARISON: Chest X-ray from [REDACTED].
#
# TECHNIQUE: Helical CT of the chest performed with IV contrast.
#
# FINDINGS:
# HEART: Cardiomegaly with left ventricular hypertrophy pattern.
# Coronary artery calcifications noted in the LAD (Agatston score ~180).
#
# LUNGS: Clear bilaterally. No pulmonary nodules or masses.
# No pleural effusion or pneumothorax.
#
# MEDIASTINUM: No lymphadenopathy. Normal caliber thoracic aorta.
#
# MUSCULOSKELETAL: Incidental note of healed right clavicle fracture with hardware.
# Degenerative changes in the cervical spine with multilevel disc disease.
# Old healed rib fractures on the right (ribs 7, 8).
#
# IMPRESSION:
# 1. Cardiomegaly with LVH, likely athletic heart with possible early
#    hypertensive changes. Cardiology follow-up recommended.
# 2. Moderate coronary artery calcification - consider risk stratification.
# 3. Chronic musculoskeletal changes consistent with prior athletic injuries.
#
# Electronically signed.

# %%
response = model.generate_content(inference_prompt + deidentified_report_2)
print("INFERENCE ATTACK RESULTS (Report #2):")
print("=" * 60)
print(response.text)
# Out:
# INFERENCE ATTACK RESULTS (Report #2):
# ============================================================
# Here's an analysis of the provided radiology report, outlining potential inferences and associated confidence levels:
#
# 1.  **Likely Age Range:**
#
#     *   **Inference:** The patient is likely in their late 30s to early 50s.
#     *   **Reasoning:** The report mentions the patient is a "former professional athlete (NFL linebacker, 12 seasons)" who retired "3 years ago".  This suggests a career that ended recently, indicating a possible age range based on the length of a typical football career. Furthermore, the presence of coronary artery calcifications (Agatston score 180), degenerative spine changes, and healed fractures are more common in middle-aged individuals.
#     *   **Confidence:** Medium
#
# 2.  **Gender:**
#
#     *   **Inference:** The patient is male.
#     *   **Reasoning:**  The profession "NFL linebacker" is almost exclusively held by men.
#     *   **Confidence:** High
#
# 3.  **Occupation Details:**
#
#     *   **Inference:** Former professional athlete, specifically an NFL linebacker.
#     *   **Reasoning:** Explicitly stated in the "Clinical History."
#     *   **Confidence:** High
#
# 4.  **Skill Level / Career Stage:**
#
#     *   **Inference:** High skill level; formerly at the peak of their career. Retired.
#     *   **Reasoning:**  Playing in the NFL for 12 seasons indicates a high level of athletic achievement and prolonged career.  The fact that they are retired shows their career has ended.
#     *   **Confidence:** High
#
# 5.  **Geographic Hints:**
#
#     *   **Inference:** None specific.
#     *   **Reasoning:** The report does not mention any specific locations.
#     *   **Confidence:** Low
#
# 6.  **Socioeconomic Indicators:**
#
#     *   **Inference:** Likely above average socioeconomic status.
#     *   **Reasoning:** Playing professional football generally leads to a high salary and financial benefits, particularly with a 12-season career. The report indicates access to medical care (CT scan).
#     *   **Confidence:** Medium
#
# 7.  **Other Identifying Characteristics:**
#
#     *   **Inference:** History of multiple concussions, non-smoker, BMI 34 (considered obese).
#     *   **Reasoning:**  These are specifically mentioned in the "Clinical History" and "Findings" sections.
#     *   **Confidence:** High

# %%
cross_reference_prompt = """
You are a privacy researcher. Given this deidentified medical report about a former
NFL linebacker, explain how someone could potentially re-identify this patient using
publicly available data sources.

Consider:
1. NFL injury reports (publicly released)
2. Sports news archives
3. Player retirement announcements
4. Social media posts about health issues
5. Public records

What specific data points in this report could be cross-referenced with public sources?

Report:
"""

response = model.generate_content(cross_reference_prompt + deidentified_report_2)
print("CROSS-REFERENCE ATTACK ANALYSIS:")
print("=" * 60)
print(response.text)
# Out:
# CROSS-REFERENCE ATTACK ANALYSIS:
# ============================================================
# Okay, as a privacy researcher, I will analyze this deidentified medical report and outline potential re-identification risks. The goal is to highlight how seemingly anonymized data can be combined with publicly available information to reveal the identity of the patient.
#
# **Data Points Vulnerable to Re-identification:**
#
# Several data points in this report, when combined with public information, significantly increase the risk of re-identification:
#
# 1.  **"Former professional athlete (NFL linebacker, 12 seasons)":** This is the biggest giveaway. The combination of sport (NFL), position (linebacker), and career length (12 seasons) narrows the field dramatically.
# 2.  **"Retired 3 years ago":** This further refines the timeframe, drastically reducing the number of potential candidates.
# 3.  **"History of multiple documented concussions":** While not definitive, it adds another layer of information that can be used to search.
# 4.  **"BMI 34. Non-smoker":** These factors are less specific but can be used as filters to narrow the list.
# 5.  **"Incidental note of healed right clavicle fracture with hardware... Old healed rib fractures on the right (ribs 7, 8)":** These are specific injuries that, combined with the other factors, can potentially be linked to injury reports and news articles.
# 6.  **"Degenerative changes in the cervical spine with multilevel disc disease":** Again, this is a very common injury among NFL players, and it could be cross-referenced with injury reports and social media.
# 7.  **"Electronically signed":** This is likely irrelevant.
# 8.  **"Cardiomegaly with LVH, likely athletic heart with possible early hypertensive changes... Moderate coronary artery calcification":** This is sensitive health information. However, while it is sensitive, it is unlikely that this information alone will lead to direct identification.
#
# **How Re-identification Could Occur:**
#
# Here's a step-by-step process someone could use to attempt re-identification:
#
# 1.  **Identify Potential Candidates:**
#     *   **NFL Player Databases/Websites:** Search websites like Pro Football Reference, ESPN, or team websites for NFL linebackers who played for 12 seasons and retired approximately 3 years ago (adjusting for potential career shifts). This initial search dramatically reduces the pool of candidates. This is a very targeted query.
#     *   **Sports News Archives:** Conduct searches on news archives (e.g., Google News, LexisNexis, etc.) for linebackers who retired around the specified timeframe. Search terms could include their name, team, and retirement year to narrow the list.
# 2.  **Cross-Reference with Health Information:**
#     *   **Injury Reports:** Review publicly available NFL injury reports from the player's career. Look for linebackers with documented concussions, clavicle fractures, rib fractures (7, 8), and neck/spine issues, matching the information in the medical report.
#     *   **News Articles and Social Media:** Search for news articles and social media posts mentioning the potential candidates and their health or post-career health concerns. Look for discussions of concussions, heart issues, and other medical issues that may align with the report.
#     *   **Player Retirement Announcements:** Examine retirement announcements to potentially cross-reference their injury history and known health issues with the medical report.
# 3.  **Confirming the Identity:**
#     *   **Combine Findings:** The more data points that align between the potential candidate's known history and the medical report, the higher the likelihood of re-identification.
#     *   **Public Records:** While less likely in this scenario, if the individual had any publicly available health-related information (e.g., a GoFundMe campaign for medical expenses), that could also provide a match.
#     *   **Cardiology follow-up:** This is sensitive information. If the potential candidate underwent public cardiology treatment, the probability of identification rises.
#
# **Specific Cross-Referencing Examples:**
#
# *   **Injury Reports:** A search for "\[Potential Player Name] concussion," "[Potential Player Name] clavicle fracture," and "[Potential Player Name] rib fracture" within relevant news archives and databases.
# *   **Social Media:** Searching for "\[Potential Player Name] health," "\[Potential Player Name] heart," or related terms on platforms such as Twitter, Facebook, or Instagram. This is the riskiest, as it can inadvertently uncover patient data.
#
# **Conclusion:**
#
# This medical report, while deidentified, is highly vulnerable to re-identification due to the specifics of the patient's career, retirement timing, and specific injury history. The combination of these details allows for targeted searches across multiple public data sources. This underscores the need for robust anonymization practices and consideration of all available public information when handling sensitive medical data.

# %% [markdown]
# ## Attack #3: The Rare Disease Problem
#
# Some conditions are so rare that the diagnosis itself becomes identifying.

# %%
deidentified_report_3 = """
EXAMINATION: MRI BRAIN WITH AND WITHOUT CONTRAST

CLINICAL HISTORY: Progressive neurological symptoms. Known diagnosis of
Creutzfeldt-Jakob disease (sporadic form), confirmed by RT-QuIC testing.
Presenting for disease progression monitoring.

COMPARISON: MRI from 6 weeks prior.

TECHNIQUE: Multiplanar multisequence MRI performed at 3T.

FINDINGS:
Interval progression of cortical ribboning with increased DWI signal involving
bilateral frontal and parietal cortices compared to prior. New involvement of
the left temporal cortex. Basal ganglia signal abnormality is stable.
Progressive cerebral atrophy noted.
No evidence of mass effect or hydrocephalus.

IMPRESSION:
1. Progressive findings consistent with known sCJD, with new left temporal
   cortical involvement.
2. Continued cerebral volume loss.

Electronically signed.
"""

print("=" * 60)
print("DEIDENTIFIED REPORT #3 (Rare Disease)")
print("=" * 60)
print(deidentified_report_3)
# Out:
# ============================================================
# DEIDENTIFIED REPORT #3 (Rare Disease)
# ============================================================
#
# EXAMINATION: MRI BRAIN WITH AND WITHOUT CONTRAST
#
# CLINICAL HISTORY: Progressive neurological symptoms. Known diagnosis of
# Creutzfeldt-Jakob disease (sporadic form), confirmed by RT-QuIC testing.
# Presenting for disease progression monitoring.
#
# COMPARISON: MRI from 6 weeks prior.
#
# TECHNIQUE: Multiplanar multisequence MRI performed at 3T.
#
# FINDINGS:
# Interval progression of cortical ribboning with increased DWI signal involving
# bilateral frontal and parietal cortices compared to prior. New involvement of
# the left temporal cortex. Basal ganglia signal abnormality is stable.
# Progressive cerebral atrophy noted.
# No evidence of mass effect or hydrocephalus.
#
# IMPRESSION:
# 1. Progressive findings consistent with known sCJD, with new left temporal
#    cortical involvement.
# 2. Continued cerebral volume loss.
#
# Electronically signed.

# %%
rare_disease_prompt = """
Analyze the re-identification risk for this deidentified report containing a rare disease.

Consider:
1. What is the annual incidence of sporadic CJD?
2. At any given time, how many active sCJD patients exist in a typical region?
3. If this report came from a specific hospital system, what's the anonymity set?
4. How does the rarity of the disease itself function as an identifier?
5. What additional data sources might exist (disease registries, research studies)?

Provide a risk assessment.

Report:
"""

response = model.generate_content(rare_disease_prompt + deidentified_report_3)
print("RARE DISEASE RE-IDENTIFICATION RISK:")
print("=" * 60)
print(response.text)
# Out:
# RARE DISEASE RE-IDENTIFICATION RISK:
# ============================================================
# Let's analyze the re-identification risk of this deidentified report.
#
# **1. What is the annual incidence of sporadic CJD?**
#
# *   Sporadic Creutzfeldt-Jakob disease (sCJD) has a very low incidence. The typical incidence is approximately **1-2 cases per million people per year**. This makes it a rare disease.
#
# **2. At any given time, how many active sCJD patients exist in a typical region?**
#
# *   This depends on the population size of the "typical region." Let's consider a hypothetical region of 1 million people. With an incidence of 1-2 per million per year, we would expect roughly **1-2 new cases per year**. However, sCJD has a rapid disease course (months). Assuming an average survival time of 6 months after diagnosis, and considering there are ongoing diagnosis, we can estimate that **1-2** patients would be active within this specific region at any given time.
#
# **3. If this report came from a specific hospital system, what's the anonymity set?**
#
# *   The anonymity set is the group of individuals within the hospital system's catchment area (the geographical area served by the hospital) who *could* potentially have this disease. This is where it gets tricky.
#     *   **Catchment Area Population:** The size of the population served by the hospital will vary. A large urban hospital might serve millions, while a rural hospital might serve a much smaller population.
#     *   **Estimated Number of sCJD patients:** Based on incidence, we'd expect very few sCJD patients within any particular hospital's service area at any given time.
#     *   **The Anonymity Set is Small:** The *very rarity* of sCJD, combined with a relatively small number of cases, results in a small anonymity set. This significantly increases re-identification risk. The anonymity set may be as small as 1-3 people depending on the hospital's service area.
#
# **4. How does the rarity of the disease itself function as an identifier?**
#
# *   **Rarity as a Key Identifier:** The diagnosis of sCJD is, in itself, a strong identifier. It narrows down the potential individuals in an area to a very small number, as we explained above.
# *   **Other Clues:** The combination of sCJD with other information in the report, like disease progression monitoring, the specific MRI findings (cortical ribboning, temporal cortex involvement, etc.), and the reference to RT-QuIC testing further increase the likelihood of re-identification. These details provide highly specific features.
#
# **5. What additional data sources might exist (disease registries, research studies)?**
#
# *   **Disease Registries:** Many countries/regions maintain disease registries for rare neurological conditions, including CJD. These registries collect information on diagnosed cases, often including demographic and clinical details. This is a HUGE risk.
# *   **Research Studies:** Research studies on CJD are ongoing. Patients diagnosed with sCJD may be enrolled in research projects or clinical trials. Researchers will collect information and this might make these patients easier to find.
# *   **Medical Records and Electronic Health Records (EHRs):** If the deidentified information can be linked to other sources of information (e.g., medical records), the re-identification risk is high.
#
# **Risk Assessment**
#
# *   **High Risk of Re-identification:** Based on the analysis, the risk of re-identification is extremely high. The combination of factors significantly increases the risk:
#     *   **Low incidence of sCJD**: The disease itself is very rare.
#     *   **Limited anonymity set**: The small number of patients in a given area.
#     *   **Specific diagnostic criteria**: The detail in the report, including the RT-QuIC testing and the MRI features (e.g. "cortical ribboning with increased DWI signal"), make this report highly specific.
#     *   **External data sources**: The existence of disease registries and potential overlap with research studies.
#
# *   **Potential Attack Vectors:**
#     *   **Internal Access:** Someone with access to the hospital's EHR system or radiology information system could cross-reference the report details with patient records.
#     *   **External Data Matching:** Someone could potentially try to match the information to data in a disease registry, research study, or a patient's public online presence.
#     *   **Local Knowledge:** In a small community or if staff knew the patient, it may be easier to identify the individual.
#
# *   **Recommendations:**
#
#     *   **Suppression/Generalization**: If the data must be released, consider the following:
#         *   Remove or generalize the diagnosis. For example, replacing "known diagnosis of Creutzfeldt-Jakob disease (sporadic form)" with "patient with progressive neurological symptoms". This is unlikely to be acceptable.
#         *   Omit the fact that the RT-QuIC confirmed the diagnosis
#         *   Reduce the level of detail provided about the specific MRI findings (e.g., instead of specific areas, use broader terms like "cortical involvement").
#     *   **K-Anonymity (or higher level of privacy):** If the hospital system insists on keeping the specific diagnosis, a very careful assessment of the catchment area and possible linking data is required. Anonymization measures may not be possible.
#     *   **Data Minimization**: Only include the absolutely essential information required.
#     *   **Access Control**: Limit access to the deidentified data to only those who absolutely need it and strictly monitor any access.
#     *   **Consider a consultation with a privacy expert.** A detailed and formal analysis is recommended before this data is released.
#
# **In summary, this deidentified report carries a substantial risk of re-identification due to the rarity of the disease and the level of detail provided. The report should be treated with extreme caution, and measures to protect patient privacy are vital.**

# %% [markdown]
# ## So... How Do We Protect Against This?
#
# Let's ask the LLM to suggest better deidentification strategies for Report #1.

# %%
mitigation_prompt = """
You are a health privacy expert. Review this "deidentified" report and suggest
additional steps needed to truly protect patient privacy.

For each quasi-identifier found:
1. Identify the risk
2. Suggest a specific mitigation (generalization, suppression, or perturbation)
3. Explain the tradeoff with clinical utility

Then provide a fully re-deidentified version of the report that balances
privacy protection with clinical usefulness.

Original "deidentified" report:
"""

response = model.generate_content(mitigation_prompt + deidentified_report_1)
print("MITIGATION RECOMMENDATIONS:")
print("=" * 60)
print(response.text)
# Out:
# 🛡️ MITIGATION RECOMMENDATIONS:
# ============================================================
# Okay, I have reviewed the "deidentified" report and will provide an assessment of its privacy risks, suggest mitigation strategies, and offer a re-deidentified version.
#
# **Analysis of Privacy Risks and Mitigation Strategies**
#
# Even though the report has been "deidentified" by removing the patient's name and institution (assuming "[REDACTED]" refers to the hospital or clinic), it still contains information that could potentially re-identify the patient. Here's a breakdown of the risks and mitigation strategies for each quasi-identifier:
#
# | Quasi-Identifier          | Risk                                                                                                                                                                                                 | Mitigation Strategy                                                                                                                                                                        | Tradeoff with Clinical Utility                                                                                                                                                              |
# | ------------------------- | ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ | ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **"Professional violinist"** |  The combination of a rare profession and a specific medical condition (left 4th finger trigger finger) significantly increases the risk of re-identification, especially within a community of violinists.     | **Generalization:** Change "Professional violinist" to a more general description like "Musician" or "Performer".  Or, remove the profession altogether.                                           | **Minor:**  Losing the specific detail of "violinist" slightly reduces the context for understanding the injury's cause. However, the core clinical information (repetitive strain) is preserved.   |
# | **"2-month history"**   |  The length of history, in combination with other details, could help narrow down a patient's identity.                                                                                              | **Suppression:** The temporal information may be preserved by generalization to "History of several weeks" or remove the temporal information altogether.                                                               | **Minimal:**  The timing is still sufficient to understand the chronicity of the condition.                                                                                                    |
# | **"6-8 hours daily"**  |  Specific information about the patient's routine may be identifiable.                                                                                                  | **Generalization:** Change "6-8 hours daily" to "Regular practice" or "Significant practice time."   | **Moderate:**  This loses some detail about the intensity of the repetitive strain. However, the clinical recommendation for activity modification will still be applicable. |
# | **"[REDACTED] Symphony Orchestra"** | The location (or institution) may be identifiable in context.   | **Suppression:** Remove the name of the orchestra entirely. Or, Generalize to "Local Orchestra". | **Minimal:**  Losing this detail does not significantly affect the clinical understanding.   |
# | **"left 4th finger"**   |  More granular information can lead to easier identification if paired with other quasi-identifiers.  | **Generalization:** Generalize to "finger".  | **Moderate:**  This removes specific anatomical information that may be relevant to the diagnosis. If the context requires the specificity, it is best to be retained. |
#
# **Revised Deidentified Report**
#
# EXAMINATION: MRI LEFT HAND WITHOUT CONTRAST
#
# CLINICAL HISTORY: Musician with history of several weeks of finger pain and weakness affecting performance. Patient reports significant practice time.
#
# COMPARISON: None available.
#
# TECHNIQUE: Multiplanar multisequence MRI of the left hand was performed on a 3T scanner.
#
# FINDINGS:
# There is intermediate T2 signal and mild enhancement within the A2 pulley of the finger, consistent with stenosing tenosynovitis (trigger finger).
# Mild associated flexor digitorum superficialis and profundus tenosynovitis is noted.
# The extensor mechanism is intact.
# No evidence of fracture or osseous abnormality.
# The triangular fibrocartilage complex is intact.
#
# IMPRESSION:
# 1. Stenosing tenosynovitis (trigger finger) of the finger with associated flexor tenosynovitis, likely related to repetitive strain from instrument playing.
# 2. Recommend hand therapy consultation and activity modification.
#
# Electronically signed.
#
# **Explanation of Changes and Balancing Privacy with Utility**
#
# *   **Profession:** Replacing "Professional violinist" with "Musician" broadens the pool of potential individuals and reduces the chances of re-identification. Removing the profession, while the most private, loses some of the context.
# *   **Practice Time:** Removing the practice time retains its general effect without divulging too much sensitive information.
# *   **Specificity of location:** The location has been removed.
# *   **Specificity of the finger:** Generalization is applied for the location of the problem.
# *   **Temporal information:** The exact temporal information has been modified without losing the context of the medical history.
#
# **Important Considerations for True De-identification**
#
# *   **Contextual Risks:** Always consider the context in which the de-identified data will be used. A small community, a specialized field, or access to other datasets can increase the risk of re-identification.
# *   **Risk Assessment:** Conduct a thorough risk assessment before sharing any de-identified data.  This helps identify potential vulnerabilities and guide appropriate mitigation strategies.
# *   **Data Minimization:**  Only include the minimum necessary information.  If a piece of information isn't crucial for the intended purpose, omit it.
# *   **Re-identification Attacks:** Be aware of potential re-identification attacks (e.g., linking the data with other publicly available datasets).
# *   **Expert Review:**  Have the de-identified data reviewed by a privacy expert to ensure the effectiveness of the de-identification process.
# *   **Documentation:**  Document the de-identification process, including the rationale for each decision and the transformations performed. This is crucial for transparency and accountability.
#
# By implementing these strategies and carefully considering the context, it is possible to create datasets that balance clinical usefulness with patient privacy.

# %% [markdown]
# ## Try It Yourself!
#
# Paste your own "deidentified" report below and see what an LLM can infer.

# %%
# Paste your own deidentified report here
your_report = """
PASTE YOUR DEIDENTIFIED REPORT HERE
"""

if your_report.strip() != "PASTE YOUR DEIDENTIFIED REPORT HERE":
    response = model.generate_content(inference_prompt + your_report)
    print("INFERENCE ATTACK ON YOUR REPORT:")
    print("=" * 60)
    print(response.text)
else:
    print("Replace the placeholder text with your report to analyze it.")

# %% [markdown]
# ## Key Takeaways
#
# 1. Standard deidentification may not be enough! Removing names, dates, and IDs doesn't eliminate all re-identification risk.
#
# 2. Occupation + condition + timing can be as identifying as a name.
#
# 3. Some diagnoses have such low prevalence that the diagnosis itself is an identifier.
#
# 4. A report from a small rural hospital vs. a large urban system has very different anonymity sets.
#
# 5. What once required manual research can now be done in seconds with inference attacks.
#
# 6. Consider generalization, suppression, k-anonymity, and differential privacy techniques.
